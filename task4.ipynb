# %%
# !ls
# Out:
# sample_data

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !mkdir test_folder

# %%
# !touch test_folder/test_file.txt

# %%
# !mkdir new_folder

# %%
# !mv test_folder/test_file.txt new_folder/

# %%
# !rmdir test_folder/
